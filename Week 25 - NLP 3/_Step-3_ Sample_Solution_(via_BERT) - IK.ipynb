# %% [markdown]
# # Install prerequisites

# %%
# !pip install transformers
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: transformers in /home/mec/.local/lib/python3.7/site-packages (4.26.0)
# Requirement already satisfied: filelock in /home/mec/.local/lib/python3.7/site-packages (from transformers) (3.9.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.11.0 in /home/mec/.local/lib/python3.7/site-packages (from transformers) (0.12.0)
# Requirement already satisfied: numpy>=1.17 in /home/mec/.local/lib/python3.7/site-packages (from transformers) (1.19.5)
# Requirement already satisfied: packaging>=20.0 in /home/mec/.local/lib/python3.7/site-packages (from transformers) (23.0)
# Requirement already satisfied: pyyaml>=5.1 in /home/mec/.local/lib/python3.7/site-packages (from transformers) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /home/mec/.local/lib/python3.7/site-packages (from transformers) (2021.11.10)
# Requirement already satisfied: requests in /home/mec/.local/lib/python3.7/site-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /home/mec/.local/lib/python3.7/site-packages (from transformers) (0.13.2)
# Requirement already satisfied: tqdm>=4.27 in /home/mec/.local/lib/python3.7/site-packages (from transformers) (4.64.1)
# Requirement already satisfied: importlib-metadata in /home/mec/.local/lib/python3.7/site-packages (from transformers) (6.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/mec/.local/lib/python3.7/site-packages (from huggingface-hub<1.0,>=0.11.0->transformers) (3.7.4.3)
# Requirement already satisfied: zipp>=0.5 in /home/mec/.local/lib/python3.7/site-packages (from importlib-metadata->transformers) (3.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/mec/.local/lib/python3.7/site-packages (from requests->transformers) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/mec/.local/lib/python3.7/site-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/lib/python3/dist-packages (from requests->transformers) (1.24.1)
# Requirement already satisfied: certifi>=2017.4.17 in /home/mec/.local/lib/python3.7/site-packages (from requests->transformers) (2020.6.20)

# %%
# !pip install PyPDF2
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting PyPDF2
#   Downloading pypdf2-3.0.1-py3-none-any.whl (232 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 1.3 MB/s eta 0:00:005.3 MB/s eta 0:00:01
# Collecting typing_extensions>=3.10.0.0 (from PyPDF2)
#   Downloading typing_extensions-4.7.1-py3-none-any.whl (33 kB)
# Installing collected packages: typing_extensions, PyPDF2
#   Attempting uninstall: typing_extensions
#     Found existing installation: typing-extensions 3.7.4.3
#     Uninstalling typing-extensions-3.7.4.3:
#       Successfully uninstalled typing-extensions-3.7.4.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-federated 0.17.0 requires dm-tree~=0.1.1, which is not installed.
# tensorflow-federated 0.17.0 requires portpicker~=1.3.1, which is not installed.
# tensorflow-federated 0.17.0 requires semantic-version~=2.8.5, which is not installed.
# tensorflow-federated 0.17.0 requires tensorflow-addons~=0.11.1, which is not installed.
# tensorflow-federated 0.17.0 requires tensorflow-model-optimization~=0.4.0, which is not installed.
# tensorflow-federated 0.17.0 requires tensorflow-privacy~=0.5.0, which is not installed.
# confection 0.0.4 requires typing-extensions<4.5.0,>=3.7.4.1; python_version < "3.8", but you have typing-extensions 4.7.1 which is incompatible.
# pycaret 3.0.2 requires numpy<1.24,>=1.21, but you have numpy 1.19.5 which is incompatible.
# sktime 0.17.0 requires numpy<1.25,>=1.21.0, but you have numpy 1.19.5 which is incompatible.
# spacy 3.5.0 requires typing-extensions<4.5.0,>=3.7.4.1; python_version < "3.8", but you have typing-extensions 4.7.1 which is incompatible.
# tensorflow 2.4.0 requires typing-extensions~=3.7.4, but you have typing-extensions 4.7.1 which is incompatible.
# tensorflow-federated 0.17.0 requires absl-py~=0.9.0, but you have absl-py 0.15.0 which is incompatible.
# tensorflow-federated 0.17.0 requires attrs~=19.3.0, but you have attrs 20.2.0 which is incompatible.
# tensorflow-federated 0.17.0 requires cachetools~=3.1.1, but you have cachetools 4.1.1 which is incompatible.
# tensorflow-federated 0.17.0 requires grpcio~=1.29.0, but you have grpcio 1.32.0 which is incompatible.
# tensorflow-federated 0.17.0 requires numpy~=1.18.4, but you have numpy 1.19.5 which is incompatible.
# tensorflow-federated 0.17.0 requires tensorflow~=2.3.0, but you have tensorflow 2.4.0 which is incompatible.
# thinc 8.1.7 requires typing-extensions<4.5.0,>=3.7.4.1; python_version < "3.8", but you have typing-extensions 4.7.1 which is incompatible.
# wasabi 1.1.1 requires typing-extensions<4.5.0,>=3.7.4.1; python_version < "3.8", but you have typing-extensions 4.7.1 which is incompatible.
# Successfully installed PyPDF2-3.0.1 typing_extensions-4.7.1

# %%
# !pip install nltk
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: nltk in /home/mec/.local/lib/python3.7/site-packages (3.5)
# Requirement already satisfied: click in /home/mec/.local/lib/python3.7/site-packages (from nltk) (8.0.3)
# Requirement already satisfied: joblib in /home/mec/.local/lib/python3.7/site-packages (from nltk) (1.2.0)
# Requirement already satisfied: regex in /home/mec/.local/lib/python3.7/site-packages (from nltk) (2021.11.10)
# Requirement already satisfied: tqdm in /home/mec/.local/lib/python3.7/site-packages (from nltk) (4.64.1)
# Requirement already satisfied: importlib-metadata in /home/mec/.local/lib/python3.7/site-packages (from click->nltk) (6.6.0)
# Requirement already satisfied: zipp>=0.5 in /home/mec/.local/lib/python3.7/site-packages (from importlib-metadata->click->nltk) (3.4.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /home/mec/.local/lib/python3.7/site-packages (from importlib-metadata->click->nltk) (4.7.1)

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /home/mec/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# # Input the TEST pdf and EMBEDDINGS

# %%
from transformers import BertTokenizer, BertModel
import PyPDF2
import re
import unicodedata
from nltk.corpus import stopwords
import pandas as pd
import torch
import numpy as np

tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
model = BertModel.from_pretrained('bert-base-uncased')

#Test pdf for evaluation
pdf_path = "Supervised Heterogeneous Domain Adaptation via Random Forests.pdf"

csv_path = "Lemmatized_Final_Dataset.csv"
text_column = "PDF"
k = 5

stop_words = set(stopwords.words('english'))
# Out:
# Downloading (…)"pytorch_model.bin";:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertModel: ['cls.predictions.decoder.weight', 'cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
df = pd.read_csv(csv_path)

# %%
df.head()
# Out:
#          AUTHOR                                             TITLES  \
# 0  Aruna Tiwari    A Quantum-Inspired Fuzzy Based Evolutionary.pdf
# 1  Aruna Tiwari  A Review of Clustering Techniques and Developm...
# 2  Aruna Tiwari  Apache Spark Based Kernelized Fuzzy Clustering...
# 3  Aruna Tiwari  Breast cancer diagnosis using Genetically Opti...
# 4  Aruna Tiwari  Enhanced Cluster Validity Index for the Evalua...
#
#                                                  PDF
# 0  see discussions ats author ofiles public ation...
# 1  review clustering techniques developments amit...
# 2  see discussions ats author ofiles public ation...
# 3  breast cancer diagnosis using genetically opti...
# 4  enhanced cluster validity index evaluation opt...

# %%
df.shape
# Out:
# (623, 3)

# %% [markdown]
# # Defining functions for subtasks

# %%
def preprocess_test_document(pdf_path):
    test_document_text = extract_text_from_pdf(pdf_path)
    preprocessed_text = preprocess_text(test_document_text)
    return preprocessed_text

def preprocess_text(text):
    if not isinstance(text, str):
        return ''
    text = text.replace('\n', ' ').replace('\r', ' ')
    text = re.sub('<[^>]*>', '', text)
    text = unicodedata.normalize('NFKD', text).encode('ascii', 'ignore').decode('utf-8', 'ignore')
    text = re.sub('http[s]?://\S+', '', text)
    text = re.sub('[^a-zA-Z]', ' ', text)
    text = text.lower()
    text = text.split()
    text = [word for word in text if word not in stop_words]
    text = [word for word in text if len(word) > 2]
    text = ' '.join(text)
    return text

def extract_text_from_pdf(pdf_path):
    try:
        with open(pdf_path, 'rb') as pdf_file:
            pdf_reader = PyPDF2.PdfReader(pdf_file)
            pdf_text = ''
            for page_num in range(len(pdf_reader.pages)):
                page = pdf_reader.pages[page_num]
                pdf_text += page.extract_text()
    except KeyError as e:
        print(f"Error processing file '{pdf_path}': {e}")
        return ''
    return pdf_text

def preprocess_csv_file(csv_path, text_column):
    data = pd.read_csv(csv_path)
    csv_text_data = data[text_column].tolist()
    preprocessed_texts = [preprocess_text(text) for text in csv_text_data]
    return preprocessed_texts

def encode_documents(documents):
    encoded_texts = tokenizer(documents, padding=True, truncation=True, return_tensors='pt')
    return encoded_texts

def generate_embeddings(encoded_texts):
    with torch.no_grad():
        model.eval()
        input_ids = encoded_texts['input_ids']
        attention_mask = encoded_texts['attention_mask']
        output = model(input_ids=input_ids, attention_mask=attention_mask)
        embeddings = output.last_hidden_state[:, 0, :]
    return embeddings

def calculate_similarity(test_embedding, csv_embeddings):
    similarity_scores = []
    indices = []
    for i, csv_embedding in enumerate(csv_embeddings):
        similarity =  torch.cosine_similarity(test_embedding, csv_embedding)
        similarity_scores.append(similarity.item())
        indices.append(i)
    return csv_embeddings, similarity_scores, indices

def retrieve_top_k_unique_authors(csv_data, similarity_scores, indices, k):
    # Sort scores and corresponding indices
    sorted_scores_indices = sorted(zip(similarity_scores, indices), key=lambda x: x[0], reverse=True)
    unique_authors = []

    # Loop over sorted scores and indices
    for _, idx in sorted_scores_indices:
        # Get author corresponding to index
        author = csv_data.iloc[idx]['AUTHOR']
        # Append author to unique_authors list if it's not there yet
        if author not in unique_authors:
            unique_authors.append(author)
            # Break the loop if we have found k unique authors
            if len(unique_authors) == k:
                break

    return unique_authors

# %%
# Preprocess the test PDF document
preprocessed_test_document = preprocess_test_document(pdf_path)

# %%
# Encode the test document and CSV document text
encoded_test_document = encode_documents([preprocessed_test_document])

# %%
# Generate embeddings for the test document
test_embedding = generate_embeddings(encoded_test_document)

# Save the test embedding to a file
np.save("test_embedding.npy", test_embedding.numpy())

# Load the test embedding from the file
test_embedding = torch.from_numpy(np.load("test_embedding.npy"))

# %%
csv_embeddings = torch.from_numpy(np.load("csv_embeddings_submission.npy"))

# %%
csv_embeddings.shape #Embedding for each document
# Out:
# torch.Size([623, 768])

# %%
# Calculate similarity between the test document and CSV documents
csv_embeddings, similarity_scores, indices = calculate_similarity(test_embedding, csv_embeddings)

# Load the CSV data
csv_data = pd.read_csv(csv_path)

# Retrieve top-k unique authors
top_k_authors = retrieve_top_k_unique_authors(csv_data, similarity_scores, indices, k)

# Print the top-k authors
print(top_k_authors)
# Out:
# ['Sanatan Sukhija, Mahindra University', 'Srishti Sharma, The Northcap University', 'Animesh Chaturvedi', 'Minni Jain', 'Krishna Asawa']

# %%
# Function to calculate similarity
def calculate_similarity_and_get_most_similar(test_embedding, csv_embeddings, csv_data):
    highest_similarity = -1
    most_similar_index = -1
    similarity_scores = []
    for i, csv_embedding in enumerate(csv_embeddings):
        similarity = torch.nn.functional.cosine_similarity(test_embedding, csv_embedding.unsqueeze(0))
        similarity_scores.append(similarity.item())
        if similarity.item() > highest_similarity:
            highest_similarity = similarity.item()
            most_similar_index = i
    author_name = csv_data.loc[most_similar_index, 'AUTHOR']  # assuming your author column is named 'AUTHOR'
    return highest_similarity * 100, most_similar_index, author_name, [score * 100 for score in similarity_scores]

# %%
highest_similarity, most_similar_index, author_name, similarity_scores = calculate_similarity_and_get_most_similar(test_embedding, csv_embeddings, csv_data)

print(f"The most similar document is at index {most_similar_index} with a similarity of {highest_similarity}%.")
print(f"The author of the most similar document is {author_name}.")
# Out:
# The most similar document is at index 445 with a similarity of 100.0%.
# The author of the most similar document is Sanatan Sukhija, Mahindra University.

# %%
def top_k_accuracy(y_true, y_pred, k=1):
    """
    Compute the top-k accuracy based on word presence in predictions.

    Parameters:
    y_true (str): True label (actual author).
    y_pred (list): List of predicted authors for the test PDFs.
                   The shape of y_pred should be (num_PDFs, k).
    k (int): The value of k for top-k accuracy. Default is 1 (top-1 accuracy).

    Returns:
    top_k_acc (float): The top-k accuracy value.
    """
    if k <= 0 or not isinstance(k, int):
        raise ValueError("k must be a positive integer.")

    num_samples = len(y_pred)
    num_correct = 0

    for i in range(num_samples):
        if y_true in y_pred[i][:k]:
            num_correct += 1

    top_k_acc = num_correct / num_samples
    return top_k_acc

# %%
# Top-3 accuracy with an example
top_k_accuracy('Sanatan',[['Sanatan','Arash','Abhinav'],['Arash','Abhinav','Vartika'],['Arash','Sanatan','Abhinav']],3)
# Out:
# 0.6666666666666666

# %%
# Top-1 accuracy (Matching with the first prediction only)
top_k_accuracy('Sanatan',[['Sanatan','Arash','Abhinav'],['Arash','Abhinav','Vartika'],['Arash','Sanatan','Abhinav']],1)
# Out:
# 0.3333333333333333

# %% [markdown]
# ## Some pointers for unbiased evaluation
# > You can split the given dataset into train and test, and evaluate the performance of your models with Top-k accuracy **for different values of k**.
#
#
# * When dividing the data, make sure that at least one PDF file from each author appears in both the training and testing sets. Exclude authors for whom there is only one PDF available in the dataset.
#
# * You can average the performance over multiple runs.
#
# * You can think of aggregating and comparing documents as a whole (per author).
