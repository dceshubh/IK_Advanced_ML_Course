# %%
def func():
    a = 2
    b = 3
    print(a,b)

def func_modify():
    global a
    a = 2
    b = 3
    print(a,b)

a = 100
b = 200
print(a,b)
func()
print(a,b)
func_modify()
print(a,b)
# Out:
# 100 200
# 2 3
# 100 200
# 2 3
# 2 200
