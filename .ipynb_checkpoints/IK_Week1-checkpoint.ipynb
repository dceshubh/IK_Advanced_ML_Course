# %%
# this is a time pass

print("My name is Shubham Varshney")
# Out:
# My name is Shubham Varshney

# %%
a = 10
b = 6.2

# %%
type(a)
# Out:
# int

# %%
a = 5
b = 5.0

print(a == b)
print(a is b)
# Out:
# True
# False

# %%
a = 5
b = 5
print(a == b)
print(a is b)
# Out:
# True
# True

# %%
for i in range(5):
    print("The value of i is :",i)
# Out:
# The value of i is : 0
# The value of i is : 1
# The value of i is : 2
# The value of i is : 3
# The value of i is : 4

# %%
print ("My name is Shubham", end = '')
print ("Varshney")
# Out:
# My name is ShubhamVarshney

# %%
a = 12
b = 1994
print (f"My birth month is {a} and year is {b}")
# Out:
# My birth month is 12 and year is 1994

# %%
def func(x: int) -> int:
    return x

print(func(2))
print(func(2.1))
print(func('Shubham'))
# Out:
# 2
# 2.1
# Shubham

# %%
list = [1, 2, 'shubham']
print(list[2])
# Out:
# shubham

# %%
def leftmost_pivot(nums):
    left_sum = 0
    for i in range(len(nums)):
        right_sum = 0
        for j in range(i+1, len(nums)):
            right_sum += nums[j]
        if left_sum == right_sum:
            return i
        left_sum += nums[i]
    return -1

nums = [1,7,3,6,5,6]
print(leftmost_pivot(nums))
# Out:
# 3

# %%
def index_first_occurrence(needle, haystack):
    return haystack.find(needle)

print(index_first_occurrence("shu", "shshubhamsakshi"))
# Out:
# 2

# %%
def get_intersection_with_maintained_frequency(a, b):
    """
    Args:
     a(list_int32)
     b(list_int32)
    Returns:
     list_int32
    """
    # Write your code here.
    dict_a = {}
    dict_b = {}
    for value in a:
        if value in dict_a:
            dict_a[value] +=1
        else:
            dict_a[value] = 1
            
    for value in b:
        if value in dict_b:
            dict_b[value] +=1
        else:
            dict_b[value] = 1
    
    intersection = []
    for value,count in dict_a.items():
        if value in dict_b:
            intersection_count = min(count, dict_b[value])
            intersection.extend([value] * intersection_count)
    
    return intersection

# %%
print(get_intersection_with_maintained_frequency([2,3,3,4], [2,2,3,3,3,4]))
# Out:
# [2, 3, 3, 4]
