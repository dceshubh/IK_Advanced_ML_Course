# %%
import numpy as np
import pandas as pd
from scipy import stats
import seaborn as sns
import math

raw_data = [20,30,40,30]
friends_salary = np.array(raw_data)

print(np.mean(friends_salary))
print(np.mean(raw_data))
# Out:
# 30.0
# 30.0

# %%
print(np.median(friends_salary))
# Out:
# 30.0

# %%
! ls
# Out:
# central_tendency.ipynb

# %%
# Using Statistical Libraries 

data = np.array([25,37,24,28,28,35,22,31,53,41,64,29,120,72])

print(np.mean(data))
print(np.median(data))
print(np.percentile(data, 50.0))
print(stats.mode(data))
print(stats.mode(data)[0])
# Out:
# 43.5
# 33.0
# 33.0
# ModeResult(mode=np.int64(28), count=np.int64(2))
# 28

# %%
import seaborn as sns
from matplotlib import pyplot as plt


plt.figure(figsize=(15,8)) # template_size
ax = sns.displot(data, kde=True)
plt.axvline(x=data.mean(), linewidth=3, color='g', label='mean',alpha=0.5)
plt.show()
